# %% [markdown]
# # Notebook with django

# %%
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings('ignore')
from IPython.display import display, Markdown
def print_md(text: str): display(Markdown(text))
from django_notebook import setup_django
setup_django()
from core import models

# %%
models.Todo.objects.count()
# Out:
# 0
